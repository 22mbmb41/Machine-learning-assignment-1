# %% [markdown]
# 1.  Import the Libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2.  Import the dataset into a dataframe (this time, for a change, you call the dataframe as 'data_sudhir' whereas last time we called it as 'df')

# %%
data_sudhir=pd.read_csv(r'C:\Users\Sudhir\Downloads\Marketing_of_Loans_dataset_shared with class.csv')

# %% [markdown]
# 3.  Display the data frame 'data_sudhir'

# %%
data_sudhir
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207       51.0                         60000
# 45209                 45208       71.0                         55000
# 45210                 45209       72.0                         55000
# 45211                 45210       57.0                         20000
# 45212                 45211       37.0                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %% [markdown]
# 4.  You will observe that the file has two extra headers which are not really looking good - hence you have to skip the first two rows while reading the dataset into dataframe 'data_sudhir' and then display it, it will look clean and neat

# %%
data_sudhir=pd.read_csv(r"C:\Users\Sudhir\Downloads\Marketing_of_Loans_dataset_shared with class.csv",skiprows=2)

# %%
data_sudhir
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %% [markdown]
# 5.  Dropping a column (We are into Feature engineering): If you think any column is not making sense or if we are not going to use it in our further analysis, we may drop them. For our exercise you may drop the 'customerid' column, since we won't be using it in our analysis.

# %%
data_sudhir.drop(['customerid'],axis=1,inplace=True)

# %% [markdown]
# 6.  After dropping that column try to display the data again to confirm if the column is dropped or not from the data frame

# %%
data_sudhir
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %% [markdown]
# 7.  The column in our dataset is having two features together, so we can split that column. The name of the column is 'jobedu'. It has two features, one is the 'job' and the other is 'education'. You can split the column extract the details into two and add those two additional columns with names viz., 'job' and 'education' to the data frame

# %%
data_sudhir['job'],data_sudhir['education']=data_sudhir['jobedu'].str.split(',',1).str

# %% [markdown]
# 8.  Display the dataframe and see if those two columns got added to the data frame at the end

# %%
data_sudhir
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %% [markdown]
# 9.  Check the null values (missing values if any). you will realise that three columns have some null values viz., 'age' 'month' 'education'

# %%
data_sudhir.isna().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# jobedu        0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %% [markdown]
# 10.  We may drop the rows with missing values, or we need to input some values into them. We may drop the rows which has missing value/ null value in 'age' column (which has about 20 missing values)

# %%
data_sudhir=data_sudhir.dropna(subset=['age'])

# %% [markdown]
# 11.  Let us input values in 'month' column. it is a categorical feature. Hence we can replace the missing values with the MODE value of the column i.e., mostly occurred column. the MODE value you can find out with the function data.month.mode() [in this data is the name of the data frame, month is the name of the column mode() is the function]

# %%
data_sudhir['month'].fillna('data_sudhir.month.mode',inplace=True)

# %% [markdown]
# 12.  Display the NULL values again, to confirm that month column does not have any missing values

# %%
data_sudhir.isna().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# jobedu        0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %% [markdown]
# 13.  'response' column also has missing values.  Since, our target column (DV) is 'response' column, if we impute the values to this column it’ll affect our analysis. So, it is better to drop the missing values from the 'response' column.

# %%
data_sudhir=data_sudhir.dropna(subset='response')

# %% [markdown]
# 14.  Display the data frame again to confirm that no more missing values are there in our data frame.

# %%
data_sudhir.isna().sum()
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# jobedu       0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response     0
# job          0
# education    0
# dtype: int64

# %%
data_sudhir
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %% [markdown]
# Taking as visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
size = data_sudhir['marital'].value_counts()
labels = 'married', "single",'divorced'
color = ['red','green', 'violet']
plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('marital', fontsize = 20)
plt.show()

# %%
size = data_sudhir['education'].value_counts()
labels = ['tertiary' ,'secondary', 'unknown' , 'primary']
color = ['red','green', 'violet','blue']
plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('education', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(15,6))

plt.subplot(1, 3, 1)
plt.title('salary')
sns.violinplot(y='salary',data=data_sudhir,color='red',linewidth=3)

plt.subplot(1, 3, 2)
plt.title('age')
sns.violinplot(y='age',data=data_sudhir,color='green',linewidth=3)

plt.subplot(1, 3, 3)
plt.title('balance')
sns.violinplot(y='balance',data=data_sudhir,color='blue',linewidth=3)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

plt.subplot(121)
sns.histplot(data=data_sudhir,x='salary',bins=30,kde=True,color='g')

plt.subplot(122)
sns.histplot(data=data_sudhir,x='salary',kde=True,hue='marital')
plt.show()

# %%
data_sudhir['new_balance']=data_sudhir['salary']+data_sudhir['balance']

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

plt.subplot(121)
sns.histplot(data=data_sudhir,x='new_balance',bins=30,kde=True,color='g')

plt.subplot(122)
sns.histplot(data=data_sudhir,x='new_balance',kde=True,hue='marital')
plt.show()
